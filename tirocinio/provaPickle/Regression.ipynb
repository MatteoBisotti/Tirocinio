# %%
import pandas as pd
import imputation as imp

dataset = pd.read_csv('/home/biso/tirocinio/provaPickle/datiLussazioniDefinitivi.csv', delimiter=';')
dataset
# Out:
#       CASE_ID  BREED  GENDER_01    AGEATSURGERYmo BODYWEIGHTKG  Taglia BCS  \
# 0           1      3          0              56,5         31,6       1   5
# 1           2      8          0               9,4         40,9       1   5
# 2           3     10          0  15,1333333333333           35       1   5
# 3           4      6          0  83,4333333333333         18,7       0   6
# 4           5      5          0  7,53333333333333         36,4       1   4
# ...       ...    ...        ...               ...          ...     ...  ..
# 3192     3193      3          0  57,4333333333333           25       1   5
# 3193     3194      5          1  49,2333333333333           38       1   6
# 3194     3195     13          0  38,0333333333333           43       1   5
# 3195     3196      5          1  11,5333333333333           28       1   5
# 3196     3197      3          0              9,53           36       1   5
#
#       INDICATIONFORTHR HIPRL  YEAR  ...  NECKSIZE  HEADSIZE   ALO  \
# 0                    4     R  2021  ...         4         1  46.0
# 1                    4     L  2021  ...         5         1  40.0
# 2                    4     R  2021  ...         4         1  42.0
# 3                    4     L  2021  ...         4         0  40.0
# 4                    4     L  2021  ...         5         1  42.0
# ...                ...   ...   ...  ...       ...       ...   ...
# 3192                 2     R  2010  ...         3         0  43.0
# 3193                 2     R  2009  ...         4         0  48.0
# 3194                 2     R  2008  ...         4         0  48.0
# 3195                 2     R  2001  ...         4         0  52.0
# 3196                 2     L  2020  ...         4         1  43.0
#
#       CUPRETROVERSION  STEMANTEVERSIONREAL  RECTUSFEMORISM.RELEASE  \
# 0                  15                 17,7                      NO
# 1                  25                 27,7                      NO
# 2                  20                 27,7                     YES
# 3                  18                 24,2                      NO
# 4                  28                 25,9                     YES
# ...               ...                  ...                     ...
# 3192               32                 27,7                      NO
# 3193               26                 25,9                      NO
# 3194                4                 11,5                      NO
# 3195               10                 31,3                      NO
# 3196               35                 17,7                      NO
#
#       first_lux_days_after_thr       DIRECTION LUX_01 LUX_CR
# 0                          NaN             NaN      0      0
# 1                          NaN             NaN      0      0
# 2                          NaN             NaN      0      0
# 3                          NaN             NaN      0      0
# 4                          NaN             NaN      0      0
# ...                        ...             ...    ...    ...
# 3192                      35.0  CRANIO-DORSALE      1      1
# 3193                      18.0  CRANIO-DORSALE      1      1
# 3194                      30.0  CRANIO-DORSALE      1      1
# 3195                      26.0  CRANIO-DORSALE      1      1
# 3196                      83.0  CRANIO-DORSALE      1      1
#
# [3197 rows x 24 columns]

# %%
dataset = imp.sub_dataset_cani(dataset)

# %%
dataset
# Out:
#      CASE_ID  BREED  GENDER_01    AGEATSURGERYmo BODYWEIGHTKG  Taglia BCS  \
# 0       3057     12          0              8,83           30       1   6
# 1       3058     11          0                14         24,8       1   4
# 2       3059      9          1              11,1         32,2       1   5
# 3       3060      3          1                10         31,8       1   5
# 4       3061      3          1              7,77         25,5       1   4
# ..       ...    ...        ...               ...          ...     ...  ..
# 418     2511      6          0  42,8666666666667         28,2       1   8
# 419     1328     10          0  12,5666666666667         33,5       1   6
# 420      678     10          0  8,46666666666667           31       1   6
# 421     2225      5          1  36,6333333333333           27       1   5
# 422      509     11          1  29,8666666666667         21,2       1   5
#
#      INDICATIONFORTHR HIPRL  YEAR  ...  NECKSIZE  HEADSIZE   ALO  \
# 0                   4     L  2019  ...         4         0  43.0
# 1                   4     L  2021  ...         4         0  38.0
# 2                   4     R  2021  ...         4         1  45.0
# 3                   4     R  2021  ...         4         1  40.0
# 4                   4     L  2018  ...         4         1  45.0
# ..                ...   ...   ...  ...       ...       ...   ...
# 418                 2     R  2021  ...         4         0  50.0
# 419                 1     R  2012  ...         5         0  37.0
# 420                 4     R  2018  ...         4         0  43.0
# 421                 4     R  1998  ...         7         1  40.0
# 422                 4     L  2019  ...         4         0  40.0
#
#      CUPRETROVERSION  STEMANTEVERSIONREAL  RECTUSFEMORISM.RELEASE  \
# 0                 16                 20,8                      NO
# 1                 20                 22,5                      NO
# 2                 15                 22,5                      NO
# 3                 16                 24,2                      NO
# 4                  8                 20,8                      NO
# ..               ...                  ...                     ...
# 418               15                 19,2                 PARTIAL
# 419               16                 27,7                      NO
# 420               18                 17,7                      NO
# 421               16                 35,3                      NO
# 422               16                 22,5                      NO
#
#      first_lux_days_after_thr       DIRECTION LUX_01 LUX_CR
# 0                        43.0  CAUDO-VENTRALE      1      0
# 1                         9.0  CAUDO-VENTRALE      1      0
# 2                        79.0  CAUDO-VENTRALE      1      0
# 3                        32.0  CRANIO-DORSALE      1      0
# 4                       222.0  CRANIO-DORSALE      1      0
# ..                        ...             ...    ...    ...
# 418                       NaN             NaN      0      1
# 419                       NaN             NaN      0      0
# 420                       NaN             NaN      0      0
# 421                       NaN             NaN      0      0
# 422                       NaN             NaN      0      0
#
# [423 rows x 24 columns]

# %%
dataset = imp.clean_dataset(dataset)
dataset
# Out:
#      CASE_ID  BREED  GENDER_01  AGEATSURGERYmo  BODYWEIGHTKG  Taglia  BCS  \
# 0       3057     12          0        8.830000          30.0       1  6.0
# 1       3058     11          0       14.000000          24.8       1  4.0
# 2       3059      9          1       11.100000          32.2       1  5.0
# 3       3060      3          1       10.000000          31.8       1  5.0
# 4       3061      3          1        7.770000          25.5       1  4.0
# ..       ...    ...        ...             ...           ...     ...  ...
# 418     2511      6          0       42.866667          28.2       1  8.0
# 419     1328     10          0       12.566667          33.5       1  6.0
# 420      678     10          0        8.466667          31.0       1  6.0
# 421     2225      5          1       36.633333          27.0       1  5.0
# 422      509     11          1       29.866667          21.2       1  5.0
#
#      INDICATIONFORTHR  HIPRL  YEAR  ...  NECKSIZE  HEADSIZE   ALO  \
# 0                   4    0.0  2019  ...         4         0  43.0
# 1                   4    0.0  2021  ...         4         0  38.0
# 2                   4    1.0  2021  ...         4         1  45.0
# 3                   4    1.0  2021  ...         4         1  40.0
# 4                   4    0.0  2018  ...         4         1  45.0
# ..                ...    ...   ...  ...       ...       ...   ...
# 418                 2    1.0  2021  ...         4         0  50.0
# 419                 1    1.0  2012  ...         5         0  37.0
# 420                 4    1.0  2018  ...         4         0  43.0
# 421                 4    1.0  1998  ...         7         1  40.0
# 422                 4    0.0  2019  ...         4         0  40.0
#
#      CUPRETROVERSION  STEMANTEVERSIONREAL  RECTUSFEMORISM.RELEASE  \
# 0                 16                 20.8                       0
# 1                 20                 22.5                       0
# 2                 15                 22.5                       0
# 3                 16                 24.2                       0
# 4                  8                 20.8                       0
# ..               ...                  ...                     ...
# 418               15                 19.2                       2
# 419               16                 27.7                       0
# 420               18                 17.7                       0
# 421               16                 35.3                       0
# 422               16                 22.5                       0
#
#      first_lux_days_after_thr       DIRECTION  LUX_01  LUX_CR
# 0                        43.0  CAUDO-VENTRALE       1       0
# 1                         9.0  CAUDO-VENTRALE       1       0
# 2                        79.0  CAUDO-VENTRALE       1       0
# 3                        32.0  CRANIO-DORSALE       1       0
# 4                       222.0  CRANIO-DORSALE       1       0
# ..                        ...             ...     ...     ...
# 418                       NaN             NaN       0       1
# 419                       NaN             NaN       0       0
# 420                       NaN             NaN       0       0
# 421                       NaN             NaN       0       0
# 422                       NaN             NaN       0       0
#
# [423 rows x 24 columns]

# %%
dataset = imp.drop_cols(dataset)

# %%
dataset
# Out:
#      BREED  GENDER_01  AGEATSURGERYmo  BODYWEIGHTKG  Taglia  BCS  \
# 0       12          0        8.830000          30.0       1  6.0
# 1       11          0       14.000000          24.8       1  4.0
# 2        9          1       11.100000          32.2       1  5.0
# 3        3          1       10.000000          31.8       1  5.0
# 4        3          1        7.770000          25.5       1  4.0
# ..     ...        ...             ...           ...     ...  ...
# 418      6          0       42.866667          28.2       1  8.0
# 419     10          0       12.566667          33.5       1  6.0
# 420     10          0        8.466667          31.0       1  6.0
# 421      5          1       36.633333          27.0       1  5.0
# 422     11          1       29.866667          21.2       1  5.0
#
#      INDICATIONFORTHR  HIPRL  YEAR  GENERATION  STEMSIZE  CUPSIZE  NECKSIZE  \
# 0                   4    0.0  2019           6         0        3         4
# 1                   4    0.0  2021           6         0        2         4
# 2                   4    1.0  2021           6         1        4         4
# 3                   4    1.0  2021           6         1        4         4
# 4                   4    0.0  2018           6         1        3         4
# ..                ...    ...   ...         ...       ...      ...       ...
# 418                 2    1.0  2021           6         3        1         4
# 419                 1    1.0  2012           4         1        3         5
# 420                 4    1.0  2018           6         1        3         4
# 421                 4    1.0  1998           1         1        8         7
# 422                 4    0.0  2019           6         3        1         4
#
#      HEADSIZE   ALO  CUPRETROVERSION  STEMANTEVERSIONREAL  \
# 0           0  43.0               16                 20.8
# 1           0  38.0               20                 22.5
# 2           1  45.0               15                 22.5
# 3           1  40.0               16                 24.2
# 4           1  45.0                8                 20.8
# ..        ...   ...              ...                  ...
# 418         0  50.0               15                 19.2
# 419         0  37.0               16                 27.7
# 420         0  43.0               18                 17.7
# 421         1  40.0               16                 35.3
# 422         0  40.0               16                 22.5
#
#      RECTUSFEMORISM.RELEASE  LUX_01  LUX_CR
# 0                         0       1       0
# 1                         0       1       0
# 2                         0       1       0
# 3                         0       1       0
# 4                         0       1       0
# ..                      ...     ...     ...
# 418                       2       0       1
# 419                       0       0       0
# 420                       0       0       0
# 421                       0       0       0
# 422                       0       0       0
#
# [423 rows x 20 columns]

# %%
dataset.isna().sum()
# Out:
# BREED                     0
# GENDER_01                 0
# AGEATSURGERYmo            0
# BODYWEIGHTKG              0
# Taglia                    0
# BCS                       2
# INDICATIONFORTHR          0
# HIPRL                     1
# YEAR                      0
# GENERATION                0
# STEMSIZE                  0
# CUPSIZE                   0
# NECKSIZE                  0
# HEADSIZE                  0
# ALO                       1
# CUPRETROVERSION           0
# STEMANTEVERSIONREAL       1
# RECTUSFEMORISM.RELEASE    0
# LUX_01                    0
# LUX_CR                    0
# dtype: int64

# %%
dataset = imp.total_imputation_regression(dataset)
# Out:
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
feature_cols = ['BREED', 'GENDER_01', 'AGEATSURGERYmo', 'BODYWEIGHTKG', 'Taglia', 'BCS', 'INDICATIONFORTHR', 'HIPRL', 
                'YEAR', 'GENERATION', 'STEMSIZE', 'CUPSIZE', 'NECKSIZE', 'HEADSIZE', 'ALO', 'CUPRETROVERSION', 'STEMANTEVERSIONREAL', 
                'RECTUSFEMORISM.RELEASE', 'LUX_CR']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

X = dataset[feature_cols]
y = dataset['LUX_01']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

model = LogisticRegression(random_state=42, max_iter=5000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=5000, random_state=42)

# %%
import pickle

# %%
with open('Logistic_Regression_Model', 'wb') as f:
    pickle.dump(model, f)
