# %%
import sys
sys.path.append("../script")
import decision_tree_original_autoencoder as dtautoencoder
# Out:
# 2024-09-29 10:40:53.904212: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-29 10:40:53.905124: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-29 10:40:53.929180: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-29 10:40:54.011871: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
dtautoencoder.main()
# Out:
# /home/biso/Tirocinio/tirocinio/model_decision_tree/../base_lib/functions.py:164: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   merged_df = df.merge(testing_set, on=df.columns.tolist(), how='inner', indicator=True)
#   criterion  max_depth  min_impurity_decrease  min_samples_split
# 0      gini          8                    0.0                  2
# [[193   7]
#  [ 70  30]]
# tn =  193
# fp =  7
# fn =  70
# tp =  30
#        Metrica    Valore
# 0     Accuracy  0.743333
# 1       Recall  0.632500
# 2    Precision  0.772326
# 3     F1-score  0.635825
# 4      ROC AUC  0.632500
# 5  Specificity  0.965000
# **MSE dell'autoencoder:** 1.9988
