# %%
import sys
sys.path.append("../script")
import decision_tree as dt
# Out:
# 2024-07-11 16:34:35.517490: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-11 16:34:35.517772: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-11 16:34:35.520835: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-11 16:34:35.552157: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
dt.main()
# Out:
#    BREED  GENDER_01  AGEATSURGERYmo  BODYWEIGHTKG  Taglia       BCS  YEAR  \
# 0      7          1       34.033333     50.000000       1  6.000000  2013
# 1     10          1       45.758435     33.186557       1  5.000000  2010
# 2      6          1       20.866667     18.500000       0  5.000000  2014
# 3     11          0       71.500000     19.500000       0  5.000000  2021
# 4      9          0        9.624567     38.108692       1  5.851449  2021
#
#    GENERATION  STEMSIZE  CUPSIZE  NECKSIZE  HEADSIZE        ALO  \
# 0           4         1        5         5         0  45.000000
# 1           4         3        2         4         0  47.186557
# 2           4         3        2         4         0  40.000000
# 3           6         2        2         4         0  45.000000
# 4           6         0        4         4         1  46.960140
#
#    CUPRETROVERSION  STEMANTEVERSIONREAL  RECTUSFEMORISM.RELEASE  LUX_CR  \
# ...
