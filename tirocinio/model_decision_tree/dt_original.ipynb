# %%
import sys
sys.path.append("../script")
import decision_tree_original as dt

# %%
dt.main()
# Out:
#   criterion  max_depth  min_impurity_decrease  min_samples_split
# 0   entropy          8                    0.0                  6
#        Metrica    Valore
# 0     Accuracy  0.938750
# 1       Recall  0.503680
# 2    Precision  0.505196
# 3     F1-score  0.503791
# 4      ROC AUC  0.503680
# 5  Specificity  0.974026
