# %% [markdown]
# ### Random forest

# %%
import sys
sys.path.append("../script")
import random_forest as rf
# Out:
# 2024-07-02 15:28:26.387059: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-02 15:28:26.387385: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-02 15:28:26.390174: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-02 15:28:26.431456: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
rf.main()
# Out:
#       BREED  GENDER_01  AGEATSURGERYmo  BODYWEIGHTKG  Taglia       BCS  YEAR  \
# 1207      7          1       34.033333     50.000000       1  6.000000  2013
# 3494     10          1       45.758435     33.186557       1  5.000000  2010
# 1183      6          1       20.866667     18.500000       0  5.000000  2014
# 100      11          0       71.500000     19.500000       0  5.000000  2021
# 3880      9          0        9.624567     38.108692       1  5.851449  2021
# ...     ...        ...             ...           ...     ...       ...   ...
# 4426      3          1       13.518386     45.742961       1  5.967354  2020
# 466      10          0        8.400000     24.300000       1  5.000000  2019
# 3092     10          1       80.570000     43.000000       1  7.000000  2006
# 3772      5          0      153.799180     40.086150       1  5.000000  2015
# 860       9          1       13.400000     36.800000       1  5.000000  2016
#
# ...
