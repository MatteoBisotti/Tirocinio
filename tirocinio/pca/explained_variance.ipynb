# %%
import sys
sys.path.append("../script")
import pca_exp_var as pca
# Out:
# 2024-08-18 10:14:15.183863: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-18 10:14:15.184175: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-18 10:14:15.187155: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-18 10:14:15.214810: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
import pandas as pd
dataset = pd.read_csv("../csv/dataset_dummy_feature.csv")
pca.main(dataset)
# Out:
# # Applicazione di PCA sul dataset
#    AGEATSURGERYmo  BODYWEIGHTKG  BCS   ALO  STEMANTEVERSIONREAL  BREED_2  \
# 0       56.500000          31.6  5.0  46.0                 17.7    False
# 1        9.400000          40.9  5.0  40.0                 27.7    False
# 2       15.133333          35.0  5.0  42.0                 27.7    False
# 3       83.433333          18.7  6.0  40.0                 24.2    False
# 4        7.533333          36.4  4.0  42.0                 25.9    False
#
#    BREED_3  BREED_4  BREED_5  BREED_6  ...  CUPRETROVERSION_34  \
# 0     True    False    False    False  ...               False
# 1    False    False    False    False  ...               False
# 2    False    False    False    False  ...               False
# 3    False    False    False     True  ...               False
# 4    False    False     True    False  ...               False
#
#    CUPRETROVERSION_35  CUPRETROVERSION_36  CUPRETROVERSION_37  \
# ...

# %% [markdown]
# Un numero di componenti sufficiente per avere un buon valore di varianza spiegata è 85.
