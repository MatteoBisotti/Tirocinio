# %%
import pandas as pd
dataset = pd.read_csv('datiLussazioniDefinitivi.csv', delimiter=';')
dataset = dataset.drop(['CASE_ID', 'n_luxation', 'first_lux_days_after_thr', 'DIRECTION'], axis = 1)
dataset = dataset.dropna()
dataset2 = dataset
dataset2
# Out:
#       BREED  GENDER_01    AGEATSURGERYmo BODYWEIGHTKG  Taglia BCS  \
# 0         3          0              56,5         31,6       1   5
# 1         8          0               9,4         40,9       1   5
# 2        10          0  15,1333333333333           35       1   5
# 3         6          0  83,4333333333333         18,7       0   6
# 4         5          0  7,53333333333333         36,4       1   4
# ...     ...        ...               ...          ...     ...  ..
# 3192      3          0  57,4333333333333           25       1   5
# 3193      5          1  49,2333333333333           38       1   6
# 3194     13          0  38,0333333333333           43       1   5
# 3195      5          1  11,5333333333333           28       1   5
# 3196      3          0              9,53           36       1   5
#
#       INDICATIONFORTHR HIPRL  YEAR  GENERATION STEMSIZE  CUPSIZE  NECKSIZE  \
# 0                    4     R  2021           6   MEDIUM        4         4
# ...

# %% [markdown]
# ## Pulizia dataset

# %%
attributi = dataset.columns
for a in attributi:
    print(a)
# Out:
# BREED
# GENDER_01
# AGEATSURGERYmo
# BODYWEIGHTKG
# Taglia
# BCS
# INDICATIONFORTHR
# HIPRL
# YEAR
# GENERATION
# STEMSIZE
# CUPSIZE
# NECKSIZE
# HEADSIZE
# ALO
# CUPRETROVERSION
# STEMANTEVERSIONREAL
# RECTUSFEMORISM.RELEASE
# LUX_01
# LUX_CR

# %% [markdown]
# ### Eliminazione valori Nan

# %%
# Valori Nan per ogni attributo
dataset.isna().sum()
# Out:
# BREED                     0
# GENDER_01                 0
# AGEATSURGERYmo            0
# BODYWEIGHTKG              0
# Taglia                    0
# BCS                       0
# INDICATIONFORTHR          0
# HIPRL                     0
# YEAR                      0
# GENERATION                0
# STEMSIZE                  0
# CUPSIZE                   0
# NECKSIZE                  0
# HEADSIZE                  0
# ALO                       0
# CUPRETROVERSION           0
# STEMANTEVERSIONREAL       0
# RECTUSFEMORISM.RELEASE    0
# LUX_01                    0
# LUX_CR                    0
# dtype: int64

# %% [markdown]
# Abbiamo 3 attributi con tantissima valori Nan, ha senso droppare queste colonne, anche perchè contengono informazioni solo per i cani che hanno subito lussazione, e non ha senso considerarli nel modello di predizione, è come vincere facile.

# %%
attributi = dataset2.columns
for a in attributi:
    print(a)
# Out:
# BREED
# GENDER_01
# AGEATSURGERYmo
# BODYWEIGHTKG
# Taglia
# BCS
# INDICATIONFORTHR
# HIPRL
# YEAR
# GENERATION
# STEMSIZE
# CUPSIZE
# NECKSIZE
# HEADSIZE
# ALO
# CUPRETROVERSION
# STEMANTEVERSIONREAL
# RECTUSFEMORISM.RELEASE
# LUX_01
# LUX_CR

# %%
dataset2.isna().sum()
# Out:
# BREED                     0
# GENDER_01                 0
# AGEATSURGERYmo            0
# BODYWEIGHTKG              0
# Taglia                    0
# BCS                       0
# INDICATIONFORTHR          0
# HIPRL                     0
# YEAR                      0
# GENERATION                0
# STEMSIZE                  0
# CUPSIZE                   0
# NECKSIZE                  0
# HEADSIZE                  0
# ALO                       0
# CUPRETROVERSION           0
# STEMANTEVERSIONREAL       0
# RECTUSFEMORISM.RELEASE    0
# LUX_01                    0
# LUX_CR                    0
# dtype: int64

# %% [markdown]
# Abbiamo ancora alcuni (pochi) valori nan sparsi nel dataset, dato che sono così pochi possono anche essere eliminati, senza il bisogno di dover fare imputation.

# %%
dataset3 = dataset2.dropna()
dataset3
# Out:
#       BREED  GENDER_01    AGEATSURGERYmo BODYWEIGHTKG  Taglia BCS  \
# 0         3          0              56,5         31,6       1   5
# 1         8          0               9,4         40,9       1   5
# 2        10          0  15,1333333333333           35       1   5
# 3         6          0  83,4333333333333         18,7       0   6
# 4         5          0  7,53333333333333         36,4       1   4
# ...     ...        ...               ...          ...     ...  ..
# 3192      3          0  57,4333333333333           25       1   5
# 3193      5          1  49,2333333333333           38       1   6
# 3194     13          0  38,0333333333333           43       1   5
# 3195      5          1  11,5333333333333           28       1   5
# 3196      3          0              9,53           36       1   5
#
#       INDICATIONFORTHR HIPRL  YEAR  GENERATION STEMSIZE  CUPSIZE  NECKSIZE  \
# 0                    4     R  2021           6   MEDIUM        4         4
# ...

# %%
dataset3.isna().sum()
# Out:
# BREED                     0
# GENDER_01                 0
# AGEATSURGERYmo            0
# BODYWEIGHTKG              0
# Taglia                    0
# BCS                       0
# INDICATIONFORTHR          0
# HIPRL                     0
# YEAR                      0
# GENERATION                0
# STEMSIZE                  0
# CUPSIZE                   0
# NECKSIZE                  0
# HEADSIZE                  0
# ALO                       0
# CUPRETROVERSION           0
# STEMANTEVERSIONREAL       0
# RECTUSFEMORISM.RELEASE    0
# LUX_01                    0
# LUX_CR                    0
# dtype: int64

# %% [markdown]
# Il dataset ora non contiene valori nan

# %% [markdown]
# ### Conversione valori stringa in valori numerici

# %%
dataset3 = dataset2
dataset3
# Out:
#       BREED  GENDER_01    AGEATSURGERYmo BODYWEIGHTKG  Taglia BCS  \
# 0         3          0              56,5         31,6       1   5
# 1         8          0               9,4         40,9       1   5
# 2        10          0  15,1333333333333           35       1   5
# 3         6          0  83,4333333333333         18,7       0   6
# 4         5          0  7,53333333333333         36,4       1   4
# ...     ...        ...               ...          ...     ...  ..
# 3192      3          0  57,4333333333333           25       1   5
# 3193      5          1  49,2333333333333           38       1   6
# 3194     13          0  38,0333333333333           43       1   5
# 3195      5          1  11,5333333333333           28       1   5
# 3196      3          0              9,53           36       1   5
#
#       INDICATIONFORTHR HIPRL  YEAR  GENERATION STEMSIZE  CUPSIZE  NECKSIZE  \
# 0                    4     R  2021           6   MEDIUM        4         4
# ...

# %%
dataset3 = dataset3.dropna()
dataset3
# Out:
#       BREED  GENDER_01    AGEATSURGERYmo BODYWEIGHTKG  Taglia BCS  \
# 0         3          0              56,5         31,6       1   5
# 1         8          0               9,4         40,9       1   5
# 2        10          0  15,1333333333333           35       1   5
# 3         6          0  83,4333333333333         18,7       0   6
# 4         5          0  7,53333333333333         36,4       1   4
# ...     ...        ...               ...          ...     ...  ..
# 3192      3          0  57,4333333333333           25       1   5
# 3193      5          1  49,2333333333333           38       1   6
# 3194     13          0  38,0333333333333           43       1   5
# 3195      5          1  11,5333333333333           28       1   5
# 3196      3          0              9,53           36       1   5
#
#       INDICATIONFORTHR HIPRL  YEAR  GENERATION STEMSIZE  CUPSIZE  NECKSIZE  \
# 0                    4     R  2021           6   MEDIUM        4         4
# ...

# %%
# HIPRL
dataset3['HIPRL'] = dataset3.HIPRL.replace('L', 0)
dataset3['HIPRL'] = dataset3.HIPRL.replace('l', 0)
dataset3['HIPRL'] = dataset3.HIPRL.replace('R', 1)

# %%
dataset3

# %%
dataset3.HIPRL.value_counts()
# Out:
# HIPRL
# 1    1602
# 0    1590
# Name: count, dtype: int64

# %%
# RECTUSFEMORISM.RELEASE
dataset3['RECTUSFEMORISM.RELEASE'].value_counts()
# Out:
# RECTUSFEMORISM.RELEASE
# NO         2588
# PARTIAL     419
# YES         183
#  NO           2
# Name: count, dtype: int64

# %%
dataset3['RECTUSFEMORISM.RELEASE'] = dataset3['RECTUSFEMORISM.RELEASE'].replace('NO', 0)
dataset3['RECTUSFEMORISM.RELEASE'] = dataset3['RECTUSFEMORISM.RELEASE'].replace(' NO', 0)
dataset3['RECTUSFEMORISM.RELEASE'] = dataset3['RECTUSFEMORISM.RELEASE'].replace('YES', 1)
dataset3['RECTUSFEMORISM.RELEASE'] = dataset3['RECTUSFEMORISM.RELEASE'].replace('PARTIAL', 2)

# %%
dataset3

# %%
dataset3['RECTUSFEMORISM.RELEASE'].value_counts()
# Out:
# RECTUSFEMORISM.RELEASE
# 0    2590
# 2     419
# 1     183
# Name: count, dtype: int64

# %%
# STEMSIZE
dataset3.STEMSIZE.value_counts()
# Out:
# STEMSIZE
# MEDIUM            1387
# LARGE              788
# SMALL              727
# X-SMALL            189
# X-LARGE GIANT       34
# X-LARGE             22
# X-LARGE MINI        21
# TIGER               13
# XX-LARGE GIANT       5
# LARGE MINI           5
# XX-LARGE             1
# Name: count, dtype: int64

# %%
valori = dataset3.STEMSIZE.unique()

count = 0
for v in valori:
    dataset3['STEMSIZE'] = dataset3['STEMSIZE'].replace(v, count)
    count += 1

# %% [markdown]
# dataset3

# %%
dataset3.STEMSIZE.value_counts()
# Out:
# STEMSIZE
# 0     1387
# 1      788
# 3      727
# 2      189
# 5       34
# 6       22
# 8       21
# 7       13
# 4        5
# 9        5
# 10       1
# Name: count, dtype: int64

# %%
dataset4 = dataset3

# %% [markdown]
# ### Conversione valori object in float64

# %%
dataset4
# Out:
#       BREED  GENDER_01    AGEATSURGERYmo BODYWEIGHTKG  Taglia BCS  \
# 0         3          0              56,5         31,6       1   5
# 1         8          0               9,4         40,9       1   5
# 2        10          0  15,1333333333333           35       1   5
# 3         6          0  83,4333333333333         18,7       0   6
# 4         5          0  7,53333333333333         36,4       1   4
# ...     ...        ...               ...          ...     ...  ..
# 3192      3          0  57,4333333333333           25       1   5
# 3193      5          1  49,2333333333333           38       1   6
# 3194     13          0  38,0333333333333           43       1   5
# 3195      5          1  11,5333333333333           28       1   5
# 3196      3          0              9,53           36       1   5
#
#       INDICATIONFORTHR  HIPRL  YEAR  GENERATION  STEMSIZE  CUPSIZE  NECKSIZE  \
# 0                    4      1  2021           6         0        4         4
# ...

# %%
tipi_attributi = dataset4.dtypes
tipi_attributi
# Out:
# BREED                       int64
# GENDER_01                   int64
# AGEATSURGERYmo             object
# BODYWEIGHTKG               object
# Taglia                      int64
# BCS                        object
# INDICATIONFORTHR            int64
# HIPRL                       int64
# YEAR                        int64
# GENERATION                  int64
# STEMSIZE                    int64
# CUPSIZE                     int64
# NECKSIZE                    int64
# HEADSIZE                    int64
# ALO                       float64
# CUPRETROVERSION             int64
# STEMANTEVERSIONREAL        object
# RECTUSFEMORISM.RELEASE      int64
# LUX_01                      int64
# LUX_CR                      int64
# dtype: object

# %%
# AGEATSURGERYmo
dataset4.AGEATSURGERYmo = dataset4.AGEATSURGERYmo.str.replace(',', '.').astype('float64')

# %%
# BODYWEIGHTKG
dataset4.BODYWEIGHTKG = dataset4.BODYWEIGHTKG.str.replace(',', '.').astype('float64')

# %%
# BCS
dataset4.BCS = dataset4.BCS.str.replace(',', '.').astype('float64')

# %%
# STEMANTEVERSIONREAL
dataset4.STEMANTEVERSIONREAL = dataset4.STEMANTEVERSIONREAL.str.replace(',', '.').astype('float64')

# %%
dataset4
# Out:
#       BREED  GENDER_01  AGEATSURGERYmo  BODYWEIGHTKG  Taglia  BCS  \
# 0         3          0       56.500000          31.6       1  5.0
# 1         8          0        9.400000          40.9       1  5.0
# 2        10          0       15.133333          35.0       1  5.0
# 3         6          0       83.433333          18.7       0  6.0
# 4         5          0        7.533333          36.4       1  4.0
# ...     ...        ...             ...           ...     ...  ...
# 3192      3          0       57.433333          25.0       1  5.0
# 3193      5          1       49.233333          38.0       1  6.0
# 3194     13          0       38.033333          43.0       1  5.0
# 3195      5          1       11.533333          28.0       1  5.0
# 3196      3          0        9.530000          36.0       1  5.0
#
#       INDICATIONFORTHR  HIPRL  YEAR  GENERATION  STEMSIZE  CUPSIZE  NECKSIZE  \
# 0                    4      1  2021           6         0        4         4
# ...

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# crea X e Y
feature_cols = ['BREED', 'GENDER_01', 'AGEATSURGERYmo', 'BODYWEIGHTKG', 'Taglia', 'BCS', 'INDICATIONFORTHR', 'HIPRL', 
                'YEAR', 'GENERATION', 'STEMSIZE', 'CUPSIZE', 'NECKSIZE', 'HEADSIZE', 'ALO', 'CUPRETROVERSION', 'STEMANTEVERSIONREAL', 
                'RECTUSFEMORISM.RELEASE', 'LUX_CR']
X = dataset4[feature_cols]
y = dataset['LUX_01']

# Si suddivide il modello tra la parte di addestramento e la parte di test
X_train, X_test, y_train, y_test = train_test_split(X, y)

# istanzia il modello 
linreg = LinearRegression()

# adatta il modello al set di addestramento
linreg.fit(X_train, y_train)

linreg.score(X_test, y_test)
# Out:
# 0.030244536567445635

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# insieme di predittori
feature_cols = ['BREED', 'GENDER_01', 'AGEATSURGERYmo', 'BODYWEIGHTKG', 'Taglia', 'BCS', 'INDICATIONFORTHR', 'HIPRL', 
                'YEAR', 'GENERATION', 'STEMSIZE', 'CUPSIZE', 'NECKSIZE', 'HEADSIZE', 'ALO', 'CUPRETROVERSION', 'STEMANTEVERSIONREAL', 
                'RECTUSFEMORISM.RELEASE', 'LUX_CR']
X = dataset4[feature_cols]

# variabile di risposta, è una variabile binaria
y = dataset['LUX_01']

# suddivisione del modello tra addestramento e test
X_train, X_test, y_train, y_test = train_test_split(X, y)

logreg = LogisticRegression()
logreg.fit(X_train, y_train)


logreg.score(X_test, y_test)


y_pred = logreg.predict(X_test)

target_names = ['class 0', 'class 1']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.95      1.00      0.97       758
#      class 1       0.00      0.00      0.00        40
#
#     accuracy                           0.95       798
#    macro avg       0.47      0.50      0.49       798
# weighted avg       0.90      0.95      0.93       798
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %% [markdown]
# Dato che nel dataset c'è un forte sbilanciamento tra le due classi, ho pensato che fosse utile adottare la tecnica dell'oversampling, per poter ampliare il campione e avere

# %%
from imblearn.over_sampling import SMOTENC

categorical_features = [True if dtype.name == 'int64'else False for dtype in X.dtypes]
smotenc = SMOTENC(categorical_features=categorical_features, random_state=42)

X_resampled, y_resampled = smotenc.fit_resample(X, y)

if not isinstance(X_resampled, pd.DataFrame):
    X_resampled = pd.DataFrame(X_resampled, columns=X.columns)  

X_resampled['target'] = y_resampled

X_resampled
# Out:
#       BREED  GENDER_01  AGEATSURGERYmo  BODYWEIGHTKG  Taglia       BCS  \
# 0         3          0       56.500000     31.600000       1  5.000000
# 1         8          0        9.400000     40.900000       1  5.000000
# 2        10          0       15.133333     35.000000       1  5.000000
# 3         6          0       83.433333     18.700000       0  6.000000
# 4         5          0        7.533333     36.400000       1  4.000000
# ...     ...        ...             ...           ...     ...       ...
# 6099      3          0       31.086494     42.186718       1  4.497628
# 6100      7          0       21.541055     50.262215       1  6.000000
# 6101      5          0      120.688154     22.051470       1  4.262868
# 6102     12          0       93.808792     38.834621       1  5.000000
# 6103     10          1       75.683601     56.130775       1  7.000000
#
#       INDICATIONFORTHR  HIPRL  YEAR  GENERATION  STEMSIZE  CUPSIZE  NECKSIZE  \
# ...

# %%
feature_cols = ['BREED', 'GENDER_01', 'AGEATSURGERYmo', 'BODYWEIGHTKG', 'Taglia', 'BCS', 'INDICATIONFORTHR', 'HIPRL', 
                'YEAR', 'GENERATION', 'STEMSIZE', 'CUPSIZE', 'NECKSIZE', 'HEADSIZE', 'ALO', 'CUPRETROVERSION', 'STEMANTEVERSIONREAL', 
                'RECTUSFEMORISM.RELEASE', 'LUX_CR']
X = X_resampled[feature_cols]

# variabile di risposta, è una variabile binaria
y = X_resampled['target']

# suddivisione del modello tra addestramento e test
X_train, X_test, y_train, y_test = train_test_split(X, y)

logreg = LogisticRegression()
logreg.fit(X_train, y_train)


logreg.score(X_test, y_test)


y_pred = logreg.predict(X_test)

target_names = ['class 0', 'class 1']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.71      0.64      0.67       782
#      class 1       0.66      0.72      0.69       744
#
#     accuracy                           0.68      1526
#    macro avg       0.68      0.68      0.68      1526
# weighted avg       0.68      0.68      0.68      1526
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_resampled[X_resampled.select_dtypes(include=['float64']).columns] = scaler.fit_transform(X_resampled.select_dtypes(include=['float64']))

X_resampled
# Out:
#       BREED  GENDER_01  AGEATSURGERYmo  BODYWEIGHTKG  Taglia       BCS  \
# 0         3          0        0.666174     -0.113465       1 -0.371909
# 1         8          0       -0.687536      0.883949       1 -0.371909
# 2        10          0       -0.522754      0.251181       1 -0.371909
# 3         6          0        1.440270     -1.496974       0  1.039156
# 4         5          0       -0.741187      0.401330       1 -1.782974
# ...     ...        ...             ...           ...     ...       ...
# 6099      3          0       -0.064241      1.021948       1 -1.080789
# 6100      7          0       -0.338588      1.888036       1  1.039156
# 6101      5          0        2.511017     -1.137533       1 -1.412051
# 6102     12          0        1.738473      0.662440       1 -0.371909
# 6103     10          1        1.217533      2.517432       1  2.450222
#
#       INDICATIONFORTHR  HIPRL  YEAR  GENERATION  STEMSIZE  CUPSIZE  NECKSIZE  \
# ...

# %%
feature_cols = ['BREED', 'GENDER_01', 'AGEATSURGERYmo', 'BODYWEIGHTKG', 'Taglia', 'BCS', 'INDICATIONFORTHR', 'HIPRL', 
                'YEAR', 'GENERATION', 'STEMSIZE', 'CUPSIZE', 'NECKSIZE', 'HEADSIZE', 'ALO', 'CUPRETROVERSION', 'STEMANTEVERSIONREAL', 
                'RECTUSFEMORISM.RELEASE', 'LUX_CR']
X = X_resampled[feature_cols]

# variabile di risposta, è una variabile binaria
y = X_resampled['target']

# suddivisione del modello tra addestramento e test
X_train, X_test, y_train, y_test = train_test_split(X, y)

logreg = LogisticRegression()
logreg.fit(X_train, y_train)


logreg.score(X_test, y_test)


y_pred = logreg.predict(X_test)

target_names = ['class 0', 'class 1']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.70      0.67      0.68       767
#      class 1       0.68      0.71      0.69       759
#
#     accuracy                           0.69      1526
#    macro avg       0.69      0.69      0.69      1526
# weighted avg       0.69      0.69      0.69      1526
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
import matplotlib.pyplot as plt

"""
from adspy_shared_utilities import (
plot_class_regions_for_classifier_subplot)

fig, subaxes = plt.subplots(1, 1, figsize=(7, 5))

plot_class_regions_for_classifier_subplot(logreg, X_train, y_train, None,
                                         None, 'Titolo',
                                         subaxes)
"""

print('Accuracy di un classificatore di regressione logistica sul training set: {:.2f}'
     .format(logreg.score(X_train, y_train)))
print('Accuracy di un classificatore di regressione logistica sul test set: {:.2f}'
     .format(logreg.score(X_test, y_test)))
# Out:
# Accuracy di un classificatore di regressione logistica sul training set: 0.70
# Accuracy di un classificatore di regressione logistica sul test set: 0.69

# %%
stratify -> train_split_test

# %%
vedere come si comporta sui dati originali

# %%
iperparametri da settare per alberi

# %%
model selection

# %%
tripartizione -> (training, validation), test

# %%
greed search cross validation

# %%
alberi di decisione profondità 5 10 15
