# %% [markdown]
# ### Imputation con media e mediana (subdataset)

# %%
import pandas as pd
import imputation as imp 
import models 

dataset = pd.read_csv('/home/biso/Tirocinio/tirocinio/Imputation/datiLussazioniDefinitivi.csv', delimiter=';')
dataset
# Out:
#       CASE_ID  BREED  GENDER_01    AGEATSURGERYmo BODYWEIGHTKG  Taglia BCS  \
# 0           1      3          0              56,5         31,6       1   5
# 1           2      8          0               9,4         40,9       1   5
# 2           3     10          0  15,1333333333333           35       1   5
# 3           4      6          0  83,4333333333333         18,7       0   6
# 4           5      5          0  7,53333333333333         36,4       1   4
# ...       ...    ...        ...               ...          ...     ...  ..
# 3192     3193      3          0  57,4333333333333           25       1   5
# 3193     3194      5          1  49,2333333333333           38       1   6
# 3194     3195     13          0  38,0333333333333           43       1   5
# 3195     3196      5          1  11,5333333333333           28       1   5
# 3196     3197      3          0              9,53           36       1   5
#
#       INDICATIONFORTHR HIPRL  YEAR  ...  NECKSIZE  HEADSIZE   ALO  \
# 0                    4     R  2021  ...         4         1  46.0
# 1                    4     L  2021  ...         5         1  40.0
# 2                    4     R  2021  ...         4         1  42.0
# 3                    4     L  2021  ...         4         0  40.0
# 4                    4     L  2021  ...         5         1  42.0
# ...                ...   ...   ...  ...       ...       ...   ...
# 3192                 2     R  2010  ...         3         0  43.0
# 3193                 2     R  2009  ...         4         0  48.0
# 3194                 2     R  2008  ...         4         0  48.0
# 3195                 2     R  2001  ...         4         0  52.0
# 3196                 2     L  2020  ...         4         1  43.0
#
#       CUPRETROVERSION  STEMANTEVERSIONREAL  RECTUSFEMORISM.RELEASE  \
# 0                  15                 17,7                      NO
# 1                  25                 27,7                      NO
# 2                  20                 27,7                     YES
# 3                  18                 24,2                      NO
# 4                  28                 25,9                     YES
# ...               ...                  ...                     ...
# 3192               32                 27,7                      NO
# 3193               26                 25,9                      NO
# 3194                4                 11,5                      NO
# 3195               10                 31,3                      NO
# 3196               35                 17,7                      NO
#
#       first_lux_days_after_thr       DIRECTION LUX_01 LUX_CR
# 0                          NaN             NaN      0      0
# 1                          NaN             NaN      0      0
# 2                          NaN             NaN      0      0
# 3                          NaN             NaN      0      0
# 4                          NaN             NaN      0      0
# ...                        ...             ...    ...    ...
# 3192                      35.0  CRANIO-DORSALE      1      1
# 3193                      18.0  CRANIO-DORSALE      1      1
# 3194                      30.0  CRANIO-DORSALE      1      1
# 3195                      26.0  CRANIO-DORSALE      1      1
# 3196                      83.0  CRANIO-DORSALE      1      1
#
# [3197 rows x 24 columns]

# %%
dataset = imp.sub_dataset_cani(dataset)
dataset = imp.clean_dataset(dataset)
dataset = imp.drop_cols(dataset)

# %%
dataset.head()
# Out:
#    BREED  GENDER_01  AGEATSURGERYmo  BODYWEIGHTKG  Taglia  BCS  \
# 0     12          0            8.83          30.0       1  6.0
# 1     11          0           14.00          24.8       1  4.0
# 2      9          1           11.10          32.2       1  5.0
# 3      3          1           10.00          31.8       1  5.0
# 4      3          1            7.77          25.5       1  4.0
#
#    INDICATIONFORTHR  HIPRL  YEAR  GENERATION  STEMSIZE  CUPSIZE  NECKSIZE  \
# 0                 4    0.0  2019           6         0        3         4
# 1                 4    0.0  2021           6         0        2         4
# 2                 4    1.0  2021           6         1        4         4
# 3                 4    1.0  2021           6         1        4         4
# 4                 4    0.0  2018           6         1        3         4
#
#    HEADSIZE   ALO  CUPRETROVERSION  STEMANTEVERSIONREAL  \
# 0         0  43.0               16                 20.8
# 1         0  38.0               20                 22.5
# 2         1  45.0               15                 22.5
# 3         1  40.0               16                 24.2
# 4         1  45.0                8                 20.8
#
#    RECTUSFEMORISM.RELEASE  LUX_01  LUX_CR
# 0                       0       1       0
# 1                       0       1       0
# 2                       0       1       0
# 3                       0       1       0
# 4                       0       1       0

# %%
dataset.isna().sum()
# Out:
# BREED                     0
# GENDER_01                 0
# AGEATSURGERYmo            0
# BODYWEIGHTKG              0
# Taglia                    0
# BCS                       2
# INDICATIONFORTHR          0
# HIPRL                     1
# YEAR                      0
# GENERATION                0
# STEMSIZE                  0
# CUPSIZE                   0
# NECKSIZE                  0
# HEADSIZE                  0
# ALO                       1
# CUPRETROVERSION           0
# STEMANTEVERSIONREAL       1
# RECTUSFEMORISM.RELEASE    0
# LUX_01                    0
# LUX_CR                    0
# dtype: int64

# %%
# faccio imputation con media e mediana
dataset = imp.total_imputation_mean_median(dataset)

# %%
dataset.isna().sum()
# Out:
# BREED                     0
# GENDER_01                 0
# AGEATSURGERYmo            0
# BODYWEIGHTKG              0
# Taglia                    0
# BCS                       0
# INDICATIONFORTHR          0
# HIPRL                     0
# YEAR                      0
# GENERATION                0
# STEMSIZE                  0
# CUPSIZE                   0
# NECKSIZE                  0
# HEADSIZE                  0
# ALO                       0
# CUPRETROVERSION           0
# STEMANTEVERSIONREAL       0
# RECTUSFEMORISM.RELEASE    0
# LUX_01                    0
# LUX_CR                    0
# dtype: int64

# %%
feature_cols = ['BREED', 'GENDER_01', 'AGEATSURGERYmo', 'BODYWEIGHTKG', 'Taglia', 'BCS', 'INDICATIONFORTHR', 'HIPRL', 
                'YEAR', 'GENERATION', 'STEMSIZE', 'CUPSIZE', 'NECKSIZE', 'HEADSIZE', 'ALO', 'CUPRETROVERSION', 'STEMANTEVERSIONREAL', 
                'RECTUSFEMORISM.RELEASE', 'LUX_CR']

# %%
X = dataset[feature_cols]
y = dataset['LUX_01']

# %% [markdown]
# ### Regressione logistica sulla feature LUX_01

# %%
model = models.logistic_regression_model(X, y)
# Out:
# Report di classificazione:
#               precision    recall  f1-score   support
#
#            0       0.67      0.91      0.77        75
#            1       0.72      0.35      0.47        52
#
#     accuracy                           0.68       127
#    macro avg       0.69      0.63      0.62       127
# weighted avg       0.69      0.68      0.65       127

# %% [markdown]
# ### Regressione logistica con cross validation

# %%
model = models.logistic_regression_cv_model(X, y, cv=5)
# Out:
# Report di classificazione:
#               precision    recall  f1-score   support
#
#            0       0.69      0.92      0.79        75
#            1       0.78      0.40      0.53        52
#
#     accuracy                           0.71       127
#    macro avg       0.73      0.66      0.66       127
# weighted avg       0.73      0.71      0.68       127

# %% [markdown]
# ### Regressione logistica con grid search cv

# %%
param_grid = {
    'C': [0.01, 0.1, 1]
}

model = models.logistic_regression_gridsearchcv_model(X=X,
                                                      y=y,
                                                      param_grid=param_grid,
                                                      cv=5,
                                                      scoring='accuracy')
# Out:
# Report di classificazione:
#               precision    recall  f1-score   support
#
#            0       0.69      0.91      0.78        75
#            1       0.75      0.40      0.53        52
#
#     accuracy                           0.70       127
#    macro avg       0.72      0.66      0.65       127
# weighted avg       0.71      0.70      0.68       127
#
# Migliori parametri: {'C': 0.1}

# %% [markdown]
# ### Albero di decisione

# %%
model = models.decision_tree_model(X=X,
                                   y=y,
                                   max_depth=15)
# Out:
# Report di classificazione:
#               precision    recall  f1-score   support
#
#            0       0.66      0.87      0.75        75
#            1       0.64      0.35      0.45        52
#
#     accuracy                           0.65       127
#    macro avg       0.65      0.61      0.60       127
# weighted avg       0.65      0.65      0.63       127

# %% [markdown]
# ### Albero di decisione con grid serch cv

# %%
param_grid = {
    'max_depth': [5, 10, 15]
}

model = models.decision_tree_gridsearchcv_model(X=X,
                                                y=y,
                                                param_grid=param_grid,
                                                cv=10,
                                                scoring='accuracy')
# Out:
# Report di classificazione:
#               precision    recall  f1-score   support
#
#            0       0.64      0.91      0.75        75
#            1       0.65      0.25      0.36        52
#
#     accuracy                           0.64       127
#    macro avg       0.64      0.58      0.55       127
# weighted avg       0.64      0.64      0.59       127
#
# Migliori parametri: {'max_depth': 5}

# %% [markdown]
# ### Random forest

# %%
model = models.random_forest_model(X=X,
                                   y=y,
                                   n_estimators=10,
                                   max_depth=10)
# Out:
# Report di classificazione:
#               precision    recall  f1-score   support
#
#            0       0.65      0.88      0.75        75
#            1       0.64      0.31      0.42        52
#
#     accuracy                           0.65       127
#    macro avg       0.64      0.59      0.58       127
# weighted avg       0.64      0.65      0.61       127

# %% [markdown]
# ### Random forest con grid search cv

# %%
param_grid = {
    'max_depth': [5, 10, 15],
    'n_estimators': [7, 9, 11, 13, 21, 100]
}

model = models.random_forest_gridsearchcv_model(X=X,
                                                y=y,
                                                param_grid=param_grid,
                                                cv=10,
                                                scoring='accuracy')
# Out:
# Report di classificazione:
#               precision    recall  f1-score   support
#
#            0       0.63      0.88      0.73        75
#            1       0.59      0.25      0.35        52
#
#     accuracy                           0.62       127
#    macro avg       0.61      0.56      0.54       127
# weighted avg       0.61      0.62      0.58       127
#
# Migliori parametri: {'max_depth': 5, 'n_estimators': 21}
