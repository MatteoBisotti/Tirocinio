# %%
import sys
sys.path.append('../base_lib')

import pandas as pd
 
import functions as func
import imputation as imp

# %%
dataset = pd.read_csv("../data/datiLussazioniDefinitivi.csv", delimiter=';')
dataset = func.clean_dataset(dataset)
dataset
# Out:
#       BREED  GENDER_01  AGEATSURGERYmo  BODYWEIGHTKG  Taglia  BCS  YEAR  \
# 0         3          0       56.500000          31.6       1  5.0  2021
# 1         8          0        9.400000          40.9       1  5.0  2021
# 2        10          0       15.133333          35.0       1  5.0  2021
# 3         6          0       83.433333          18.7       0  6.0  2021
# 4         5          0        7.533333          36.4       1  4.0  2021
# ...     ...        ...             ...           ...     ...  ...   ...
# 3192      3          0       57.433333          25.0       1  5.0  2010
# 3193      5          1       49.233333          38.0       1  6.0  2009
# 3194     13          0       38.033333          43.0       1  5.0  2008
# 3195      5          1       11.533333          28.0       1  5.0  2001
# 3196      3          0        9.530000          36.0       1  5.0  2020
#
#       n_luxation  GENERATION  STEMSIZE  ...  NECKSIZE  HEADSIZE   ALO  \
# 0           -1.0           6         0  ...         4         1  46.0
# 1           -1.0           6         1  ...         5         1  40.0
# 2           -1.0           6         0  ...         4         1  42.0
# 3           -1.0           6         2  ...         4         0  40.0
# 4           -1.0           6         1  ...         5         1  42.0
# ...          ...         ...       ...  ...       ...       ...   ...
# 3192         1.0           4         3  ...         3         0  43.0
# 3193         1.0           4         0  ...         4         0  48.0
# 3194         2.0           3         1  ...         4         0  48.0
# 3195         1.0           2         0  ...         4         0  52.0
# 3196         2.0           6         3  ...         4         1  43.0
#
#       CUPRETROVERSION  STEMANTEVERSIONREAL  RECTUSFEMORISM.RELEASE  \
# 0                  15                 17.7                       0
# 1                  25                 27.7                       0
# 2                  20                 27.7                       1
# 3                  18                 24.2                       0
# 4                  28                 25.9                       1
# ...               ...                  ...                     ...
# 3192               32                 27.7                       0
# 3193               26                 25.9                       0
# 3194                4                 11.5                       0
# 3195               10                 31.3                       0
# 3196               35                 17.7                       0
#
#       first_lux_days_after_thr  DIRECTION  LUX_01  LUX_CR
# 0                         -1.0       -1.0       0       0
# 1                         -1.0       -1.0       0       0
# 2                         -1.0       -1.0       0       0
# 3                         -1.0       -1.0       0       0
# 4                         -1.0       -1.0       0       0
# ...                        ...        ...     ...     ...
# 3192                      35.0        0.0       1       1
# 3193                      18.0        0.0       1       1
# 3194                      30.0        0.0       1       1
# 3195                      26.0        0.0       1       1
# 3196                      83.0        0.0       1       1
#
# [3197 rows x 21 columns]

# %%
dataset[dataset.isnull().any(axis=1)]
# Out:
#       BREED  GENDER_01  AGEATSURGERYmo  BODYWEIGHTKG  Taglia  BCS  YEAR  \
# 505      10          1       31.400000          26.4       1  5.0  2019
# 1397     10          0        7.600000          28.0       1  NaN  2011
# 2327      3          0       14.866667          70.0       1  5.0  2018
# 3176      7          0       14.100000          56.0       1  NaN  2011
#
#       n_luxation  GENERATION  STEMSIZE  ...  NECKSIZE  HEADSIZE   ALO  \
# 505         -1.0           6         3  ...         4         0  45.0
# 1397        -1.0           4         0  ...         4         0  42.0
# 2327        -1.0           6         7  ...        10         4   NaN
# 3176         1.0           4         1  ...         4         1  40.0
#
#       CUPRETROVERSION  STEMANTEVERSIONREAL  RECTUSFEMORISM.RELEASE  \
# 505                18                  NaN                       0
# 1397               20                 31.3                       0
# 2327               28                 25.9                       0
# 3176               15                 39.5                       0
#
#       first_lux_days_after_thr  DIRECTION  LUX_01  LUX_CR
# 505                       -1.0       -1.0       0       0
# 1397                      -1.0       -1.0       0       0
# 2327                      -1.0       -1.0       0       0
# 3176                    1626.0        0.0       1       1
#
# [4 rows x 21 columns]

# %%
dataset.isna().sum()
# Out:
# BREED                       0
# GENDER_01                   0
# AGEATSURGERYmo              0
# BODYWEIGHTKG                0
# Taglia                      0
# BCS                         2
# YEAR                        0
# n_luxation                  0
# GENERATION                  0
# STEMSIZE                    0
# CUPSIZE                     0
# NECKSIZE                    0
# HEADSIZE                    0
# ALO                         1
# CUPRETROVERSION             0
# STEMANTEVERSIONREAL         1
# RECTUSFEMORISM.RELEASE      0
# first_lux_days_after_thr    0
# DIRECTION                   0
# LUX_01                      0
# LUX_CR                      0
# dtype: int64

# %%
binary_features = ['GENDER_01', 'Taglia', 'LUX_CR', 'LUX_01']
dataset_imputed = imp.knn_imputation(dataset, binary_features)

dataset_imputed.isna().sum()
# Out:
# Miglior parametro n_neighbors: 3
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /home/biso/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan]
#   warnings.warn(
# BREED                       0
# GENDER_01                   0
# AGEATSURGERYmo              0
# BODYWEIGHTKG                0
# Taglia                      0
# BCS                         0
# YEAR                        0
# n_luxation                  0
# GENERATION                  0
# STEMSIZE                    0
# CUPSIZE                     0
# NECKSIZE                    0
# HEADSIZE                    0
# ALO                         0
# CUPRETROVERSION             0
# STEMANTEVERSIONREAL         0
# RECTUSFEMORISM.RELEASE      0
# first_lux_days_after_thr    0
# DIRECTION                   0
# LUX_01                      0
# LUX_CR                      0
# dtype: int64

# %%
cols = ['BCS', 'STEMANTEVERSIONREAL', 'ALO']

for col in cols:
    func.plot_boxplot(dataset, dataset_imputed, col)
