# %% [markdown]
# ### Confronto tra le matrici di correlazione

# %%
import pandas as pd

import sys 
sys.path.append("../base_lib")
import functions as func
# Out:
# 2025-01-15 16:56:34.359460: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-15 16:56:34.359771: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-15 16:56:34.362145: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-15 16:56:34.391721: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
dataset = pd.read_csv("../csv/dataset_original.csv")
dataset_SMOTENC = pd.read_csv("../csv/dataset_SMOTENC.csv")
dataset_autoencoder = pd.read_csv("../csv/dataset_original_autoencoder.csv")

dataset = func.drop_cols(dataset)
dataset_SMOTENC = func.drop_cols(dataset_SMOTENC)
dataset_autoencoder = dataset_autoencoder.drop(['Unnamed: 0', 'mse'], axis=1)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15, 12))
plt.scatter(dataset['YEAR'], dataset['GENERATION'])
plt.xlabel('Anno')
plt.ylabel('Generazione della protesi')
plt.show()

# %%
dataset['YEAR'].corr(dataset['GENERATION'])
# Out:
# 0.9628511444983815

# %%
plt.figure(figsize=(15, 12))
plt.title("Scatter plot tra il peso del cane e la dimensione della protesi CUP")
plt.scatter(dataset['BODYWEIGHTKG'], dataset['CUPSIZE'])
plt.xlabel('Peso')
plt.ylabel('Dimensione della protesi')
plt.show()

print(dataset['BODYWEIGHTKG'].corr(dataset['CUPSIZE']))
# Out:
# 0.7295680163241569

# %%
plt.figure(figsize=(15, 12))
plt.title("Scatter plot tra il peso del cane e la dimensione della protesi HEAD")
plt.scatter(dataset['BODYWEIGHTKG'], dataset['HEADSIZE'])
plt.xlabel('Peso')
plt.ylabel('Dimensione della protesi')
plt.show()

print(dataset['BODYWEIGHTKG'].corr(dataset['HEADSIZE']))
# Out:
# 0.5081160683792697

# %%
plt.figure(figsize=(15, 12))
plt.title("Scatter plot tra il peso del cane e la dimensione della protesi NECK")
plt.scatter(dataset['BODYWEIGHTKG'], dataset['NECKSIZE'])
plt.xlabel('Peso')
plt.ylabel('Dimensione della protesi')
plt.show()

print(dataset['BODYWEIGHTKG'].corr(dataset['NECKSIZE']))
# Out:
# 0.5677294796100625

# %%
import matplotlib.pyplot as plt

# Creazione della figura e dei subplot
fig, axs = plt.subplots(1, 3, figsize=(20, 6))  # 1 riga, 3 colonne

# Primo scatter plot
axs[0].scatter(dataset['BODYWEIGHTKG'], dataset['NECKSIZE'])
axs[0].set_title("Protesi NECK")
axs[0].set_xlabel('Peso')
axs[0].set_ylabel('Dimensione della protesi')

# Secondo scatter plot
axs[1].scatter(dataset['BODYWEIGHTKG'], dataset['HEADSIZE'])
axs[1].set_title("Protesi HEAD")
axs[1].set_xlabel('Peso')
axs[1].set_ylabel('Dimensione della protesi')

# Terzo scatter plot
axs[2].scatter(dataset['BODYWEIGHTKG'], dataset['CUPSIZE'])
axs[2].set_title("Protesi CUP")
axs[2].set_xlabel('Peso')
axs[2].set_ylabel('Dimensione della protesi')

# Regola lo spazio tra i plot
plt.tight_layout()

# Visualizza la figura
plt.show()

# %%
import matplotlib.pyplot as plt

# Creazione della figura e dei subplot
fig, axs = plt.subplots(2, 2, figsize=(18, 12))  # 2 righe, 2 colonne

# Primo scatter plot (prima riga, prima colonna)
axs[0, 0].scatter(dataset['BODYWEIGHTKG'], dataset['NECKSIZE'])
axs[0, 0].set_title("Scatter plot tra il peso del cane e la dimensione della protesi NECK")
axs[0, 0].set_xlabel('Peso  ')
axs[0, 0].set_ylabel('Dimensione della protesi')

# Secondo scatter plot (prima riga, seconda colonna)
axs[0, 1].scatter(dataset['BODYWEIGHTKG'], dataset['HEADSIZE'])
axs[0, 1].set_title("Scatter plot tra il peso del cane e la dimensione della protesi HEAD")
axs[0, 1].set_xlabel('Peso')
axs[0, 1].set_ylabel('Dimensione della protesi')

# Terzo scatter plot (seconda riga, seconda colonna)
axs[1, 0].scatter(dataset['BODYWEIGHTKG'], dataset['CUPSIZE'])
axs[1, 0].set_title("Scatter plot tra il peso del cane e la dimensione della protesi CUP")
axs[1, 0].set_xlabel('Peso')
axs[1, 0].set_ylabel('Dimensione della protesi')

# Nascondere l'asse vuoto (seconda riga, prima colonna)
axs[1, 1].axis('off')

# Regola lo spazio tra i plot
plt.tight_layout()

# Visualizza la figura
plt.show()

# %%
func.display_corr_matrix(dataset, "Matrice di correlazione dataset originale")
# Out:
#                            BREED  GENDER_01  AGEATSURGERYmo  BODYWEIGHTKG  \
# BREED                   1.000000   0.027166       -0.014028     -0.025418
# GENDER_01               0.027166   1.000000       -0.027979     -0.245394
# AGEATSURGERYmo         -0.014028  -0.027979        1.000000      0.223443
# BODYWEIGHTKG           -0.025418  -0.245394        0.223443      1.000000
# Taglia                  0.110383  -0.086088        0.081939      0.473659
# BCS                     0.139797   0.055765        0.249440      0.347751
# YEAR                    0.065465   0.008949       -0.073647     -0.098832
# GENERATION              0.058535   0.010490       -0.065173     -0.101435
# STEMSIZE               -0.078307  -0.003698       -0.042595     -0.145992
# CUPSIZE                -0.077249  -0.186105        0.055544      0.729568
# NECKSIZE               -0.075571  -0.125310        0.119718      0.567729
# HEADSIZE               -0.058671  -0.131631        0.001310      0.508116
# ...

# %%
func.display_corr_matrix(dataset_SMOTENC, "Matrice di correlazione dataset aumentato con SMOTENC")
# Out:
#                            BREED  GENDER_01  AGEATSURGERYmo  BODYWEIGHTKG  \
# BREED                   1.000000  -0.001573       -0.002249     -0.048865
# GENDER_01              -0.001573   1.000000       -0.066169     -0.262410
# AGEATSURGERYmo         -0.002249  -0.066169        1.000000      0.183790
# BODYWEIGHTKG           -0.048865  -0.262410        0.183790      1.000000
# Taglia                  0.115529  -0.119731        0.063676      0.429712
# BCS                     0.102625   0.062898        0.223496      0.326588
# YEAR                    0.043100   0.023891       -0.129407     -0.130000
# GENERATION              0.011481   0.034737       -0.102382     -0.129552
# STEMSIZE               -0.092547   0.059600       -0.008748     -0.158471
# CUPSIZE                -0.069130  -0.213529        0.013844      0.645874
# NECKSIZE               -0.082881  -0.135591        0.103433      0.532163
# HEADSIZE               -0.071590  -0.140992       -0.025405      0.452675
# ...

# %%
func.display_corr_matrix(dataset_autoencoder, "Matrice di correlazione dataset aumentato con autoencoder")
# Out:
#                            BREED  GENDER_01  AGEATSURGERYmo  BODYWEIGHTKG  \
# BREED                   1.000000   0.035294       -0.030775     -0.028876
# GENDER_01               0.035294   1.000000       -0.031649     -0.254826
# AGEATSURGERYmo         -0.030775  -0.031649        1.000000      0.173606
# BODYWEIGHTKG           -0.028876  -0.254826        0.173606      1.000000
# Taglia                  0.125059  -0.108311        0.070017      0.474744
# BCS                     0.155381   0.068947        0.210529      0.322173
# YEAR                    0.047507   0.026186       -0.067441     -0.160699
# GENERATION              0.037148   0.021770       -0.052416     -0.161584
# STEMSIZE               -0.049063   0.041882       -0.017437     -0.200499
# CUPSIZE                -0.082547  -0.197818       -0.000918      0.730021
# NECKSIZE               -0.080507  -0.135378        0.096844      0.565978
# HEADSIZE               -0.082712  -0.128979       -0.017838      0.499333
# ...
