# %% [markdown]
# ### Confronto tra le matrici di correlazione

# %%
import pandas as pd

import sys 
sys.path.append("../base_lib")
import functions as func
# Out:
# 2024-07-09 18:37:02.731534: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-09 18:37:02.731882: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-09 18:37:02.734486: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-09 18:37:02.784748: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-09 18:37:03.874925: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
dataset = pd.read_csv("../csv/dataset_original.csv")
dataset_SMOTENC = pd.read_csv("../csv/dataset_SMOTENC.csv")
dataset_encoder = pd.read_csv("../csv/dataset_encoder.csv")

dataset = func.drop_cols(dataset)
dataset_SMOTENC = func.drop_cols(dataset_SMOTENC)
dataset_encoder = func.drop_cols(dataset_encoder)

# %%
func.diplay_corr_matrix(dataset)

# %%
func.diplay_corr_matrix(dataset_SMOTENC)

# %%
func.diplay_corr_matrix(dataset_encoder)
