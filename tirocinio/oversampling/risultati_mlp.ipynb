# %% [markdown]
# ### Risultati MLP Regressor

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("../csv/dataset_encoder.csv")
dataset
# Out:
#           BREED  GENDER_01  AGEATSURGERYmo  BODYWEIGHTKG    Taglia       BCS  \
# 0      7.000000   1.000000       34.033333     50.000000  1.000000  6.000000
# 1      6.374599   0.519371       28.032867     35.556554  0.865447  5.187598
# 2      6.000000   1.000000       20.866667     18.500000  0.000000  5.000000
# 3     11.000000   0.000000       71.500000     19.500000  0.000000  5.000000
# 4      6.767737   0.372514       31.553140     35.489605  0.901365  5.076883
# ...         ...        ...             ...           ...       ...       ...
# 4579   6.509846   0.489580       33.875207     36.512670  0.870823  5.112389
# 4580  10.000000   0.000000        8.400000     24.300000  1.000000  5.000000
# 4581  10.000000   1.000000       80.570000     43.000000  1.000000  7.000000
# 4582   6.617464   0.463753       35.091518     35.028784  0.906663  4.974492
# 4583   9.000000   1.000000       13.400000     36.800000  1.000000  5.000000
#
# ...

# %%
import sys
sys.path.append("../base_lib")
import functions as func

# %%
dataset = func.drop_cols(dataset)
df = dataset.drop(['mse'], axis=1)
func.display_corr_matrix(df)
# Out:
#                            BREED  GENDER_01  AGEATSURGERYmo  BODYWEIGHTKG  \
# BREED                   1.000000   0.029116        0.000178     -0.054850
# GENDER_01               0.029116   1.000000       -0.024919     -0.245236
# AGEATSURGERYmo          0.000178  -0.024919        1.000000      0.194223
# BODYWEIGHTKG           -0.054850  -0.245236        0.194223      1.000000
# Taglia                  0.112039  -0.089265        0.082779      0.456401
# BCS                     0.157302   0.057762        0.261272      0.300023
# YEAR                    0.092926   0.013699       -0.050700     -0.143542
# GENERATION              0.087272   0.019990       -0.039171     -0.148643
# STEMSIZE               -0.079445  -0.005596       -0.043480     -0.137876
# CUPSIZE                -0.091772  -0.194322        0.040503      0.730095
# NECKSIZE               -0.071735  -0.124941        0.121753      0.546625
# HEADSIZE               -0.051840  -0.135903        0.003952      0.483515
# ...

# %%
def plot_outcome_feature(df, feature_name):
    value_counts = df[feature_name].value_counts()

    value_counts_df = value_counts.reset_index()
    value_counts_df.columns = ['Value', 'Count']

    plt.figure(figsize=(10, 6))
    sns.barplot(x='Value', y='Count', data=value_counts_df, palette='deep')

    plt.xlabel('Classe')
    plt.ylabel('Conteggio valori')
    plt.show()

plot_outcome_feature(df, "LUX_01")

# %%
df['LUX_01'].value_counts()
# Out:
# LUX_01
# 0    3056
# 1    1528
# Name: count, dtype: int64
